# %%
import pickle
import numpy as np

QuestDic=pickle.load(open("A50773_Ficha4_Respostas.p",'rb'))

QuestDic
# Out:
# {'Q001': array([[0., 1., 0., 0.],
#         [0., 1., 0., 0.]]),
#  'Q002': array([[1., 0., 0., 0.],
#         [1., 0., 0., 0.]]),
#  'Q003': array([[0., 1., 0., 0.],
#         [1., 0., 0., 0.]]),
#  'nome': 'Rafael Alexandre Besteiro Dias',
#  'numero': 'A50773'}
